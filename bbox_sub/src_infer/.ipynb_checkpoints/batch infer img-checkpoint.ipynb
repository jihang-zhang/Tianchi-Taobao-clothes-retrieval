# %%
from infer_img import *

# %%
inst_ds = get_pred_img('../../input/validation_dataset_part1/image')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 5000/5000 [00:01<00:00, 2685.78it/s]
# using cosine layer
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 28/28 [00:08<00:00,  3.28it/s]

# %%
inst_ds[-15]
# Out:
# {'file_name': '../../input/validation_dataset_part1/image/001645/1.jpg',
#  'height': 800,
#  'width': 800,
#  'item_id': '001645',
#  'type': 'image',
#  'bbox': [229, 22, 548, 778],
#  'score': 0.997787356376648,
#  'bbox_aspect': 0.421957671957672,
#  'aspect_group': 2,
#  'feat': [0.07581817358732224,
#   -0.05067245289683342,
#   0.012398162856698036,
#   -0.01395690068602562,
#   -0.03615764528512955,
#   -0.023070985451340675,
#   0.018611563369631767,
#   0.032739270478487015,
#   -0.06082642823457718,
#   0.020415199920535088,
#   0.010319114662706852,
#   -0.05381931737065315,
#   -0.029176820069551468,
#   -0.036551281809806824,
#   -0.03877662867307663,
#   -0.060441531240940094,
#   -0.04532082378864288,
#   0.021239884197711945,
#   0.0058607663959264755,
#   -0.028380481526255608,
#   -0.02442200481891632,
#   0.058340173214673996,
#   0.03154062107205391,
#   0.04988424852490425,
#   -0.00392179237678647,
#   0.042579151690006256,
#   0.015087530016899109,
# ...

# %%
inst_ds[-15]
# Out:
# {'file_name': '../../input/validation_dataset_part1/image/001645/1.jpg',
#  'height': 800,
#  'width': 800,
#  'item_id': '001645',
#  'type': 'image',
#  'bbox': [229, 22, 548, 778],
#  'score': 0.997787356376648,
#  'bbox_aspect': 0.421957671957672,
#  'aspect_group': 2,
#  'feat': [0.07581817358732224,
#   -0.05067245289683342,
#   0.012398162856698036,
#   -0.01395690068602562,
#   -0.03615764528512955,
#   -0.023070985451340675,
#   0.018611563369631767,
#   0.032739270478487015,
#   -0.06082642823457718,
#   0.020415199920535088,
#   0.010319114662706852,
#   -0.05381931737065315,
#   -0.029176820069551468,
#   -0.036551281809806824,
#   -0.03877662867307663,
#   -0.060441531240940094,
#   -0.04532082378864288,
#   0.021239884197711945,
#   0.0058607663959264755,
#   -0.028380481526255608,
#   -0.02442200481891632,
#   0.058340173214673996,
#   0.03154062107205391,
#   0.04988424852490425,
#   -0.00392179237678647,
#   0.042579151690006256,
#   0.015087530016899109,
# ...
