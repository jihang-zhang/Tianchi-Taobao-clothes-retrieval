# %%
from infer_vid import *

# %%
inst_ds = get_pred_vid('../../input/validation_dataset_part1/video')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 5000/5000 [00:07<00:00, 707.52it/s]
# using cosine layer
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [00:08<00:00,  2.67it/s]

# %%
inst_ds[-20]
# Out:
# {'file_name': '../../input/validation_dataset_part1/video/000919.mp4',
#  'height': 960,
#  'width': 540,
#  'item_id': '000919',
#  'type': 'video',
#  'bbox': [99, 359, 318, 814],
#  'score': 0.9992340803146362,
#  'frame': 280,
#  'bbox_aspect': 0.48131868131868133,
#  'aspect_group': 3,
#  'feat': [0.10861119627952576,
#   -0.02023276872932911,
#   0.000677834206726402,
#   0.04453166946768761,
#   -0.08077826350927353,
#   0.013814250938594341,
#   -0.008523191325366497,
#   -0.0611051470041275,
#   -0.0397714264690876,
#   0.03194702789187431,
#   -0.0006806030287407339,
#   -0.019916066899895668,
#   0.07606640458106995,
#   0.009971742518246174,
#   -0.013884657062590122,
#   -0.021979905664920807,
#   0.08041248470544815,
#   -0.0171558428555727,
#   0.01628359965980053,
#   0.027200501412153244,
#   0.010065089911222458,
#   0.01591976173222065,
#   0.0682348683476448,
#   -0.04079398885369301,
#   0.0012808083556592464,
#   0.0553743839263916,
#   -0.01839214749634266,
# ...

# %%
inst_ds[-20]
# Out:
# {'file_name': '../../input/validation_dataset_part1/video/000919.mp4',
#  'height': 960,
#  'width': 540,
#  'item_id': '000919',
#  'type': 'video',
#  'bbox': [99, 359, 318, 814],
#  'score': 0.9992340803146362,
#  'frame': 280,
#  'bbox_aspect': 0.48131868131868133,
#  'aspect_group': 3,
#  'feat': [0.10861119627952576,
#   -0.02023276872932911,
#   0.000677834206726402,
#   0.04453166946768761,
#   -0.08077826350927353,
#   0.013814250938594341,
#   -0.008523191325366497,
#   -0.0611051470041275,
#   -0.0397714264690876,
#   0.03194702789187431,
#   -0.0006806030287407339,
#   -0.019916066899895668,
#   0.07606640458106995,
#   0.009971742518246174,
#   -0.013884657062590122,
#   -0.021979905664920807,
#   0.08041248470544815,
#   -0.0171558428555727,
#   0.01628359965980053,
#   0.027200501412153244,
#   0.010065089911222458,
#   0.01591976173222065,
#   0.0682348683476448,
#   -0.04079398885369301,
#   0.0012808083556592464,
#   0.0553743839263916,
#   -0.01839214749634266,
# ...
